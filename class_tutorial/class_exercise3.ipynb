# %% [markdown]
# # Data Visualisation
#
# As the saying goes, a picture is worth a thousand words. This is definitely true in the field of data science. For this reason, we are now devoting ourselves to the work of data visualisation.
#
# We continue to work with the Penguin data set. Actually, I don't have to say it anymore because you're already a professional. But I'll mention it anyway, otherwise the Tidyverse and palmerpenguins packages will feel left out.

# %%
# load the packages
???(???)
???(???)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# In this exercise, you're tasked with completing the code snippet to generate a scatter plot using the `ggplot2` package. The plot aims to analyze the physical traits of different penguin species from the `penguins` dataset. Your challenge is to fill in the missing parts of the code, denoted by `???`, with the appropriate code segments to create a fully functional plot.
#
# Here's what you need to do:
#
# - **First ??? in `ggplot(???)`**: Specify the dataset that contains the data you want to plot. Remember, we are working with a dataset that includes various measurements for different penguin species.
#
# - **Second and third ??? in `aes(x = ???, y = ???)`**: Identify the variables from the dataset that you want to plot on the x and y axes. For this exercise, choose two continuous variables that you think would illustrate an interesting relationship.
#
# - **Fourth ??? in `aes(..., ??? = species)`**: This is where you specify how to differentiate the data points by penguin species. Use the correct aesthetic property to color the points according to the `species` column in the dataset.
#
# - **`geom_point(???? = 0.4)`**: Replace `????` with the correct argument name to adjust the transparency of the points in the scatter plot. This will help in visualizing overlapping points more effectively.
#
# - **First ??? in `labs(??? = "Penguin Physical Traits Analysis")`**: This argument sets the title of the plot. Replace `???` with the correct argument name for the plot title.
#
# - **Second and third ??? in the `labs` function**: Replace the `???` with the correct names of the variables you chose for the x and y axes. This ensures that your plot axes are correctly labeled, reflecting the variables being plotted.
#
# Your objective is to fill in these blanks correctly to produce a meaningful and visually appealing scatter plot. This exercise will test your understanding of the `ggplot2` syntax and your ability to visualize data effectively. Good luck, and remember to explore the data and enjoy the process of discovery!

# %%
ggplot(???, aes(x = ???, y = ???, ??? = species)) +
  geom_point(???? = 0.4) + # Add points
  labs(??? = "Penguin Physical Traits Analysis",
       x = "???",
       y = "???")
# Out:
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title

# %% [markdown]
# ss of discovery!
